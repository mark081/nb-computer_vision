# %% [markdown]
# ## Copying Images

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
imageBGR = cv2.imread('Images/markandlori.png')
imageRGB = cv2.cvtColor(imageBGR,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imageRGB)

# %%
id(imageRGB)
# Out:
# 5759857840

# %%
id(imageRGB.copy())
# Out:
# 5758802736

# %% [markdown]
# ## Flip It

# %% [markdown]
# ### Manually

# %%
width, height, C = imageRGB.shape

# %%
#Create an zero-filled array of the flipped size
